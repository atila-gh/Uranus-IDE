# %% [markdown]
# ### import below code in Uranus and see Object Viewer Table

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import io, re, types, weakref, array, queue, threading, asyncio
import datetime, decimal, fractions, uuid, pathlib, collections

# Built-in types
a_int = 1
a_float = 3.14
a_complex = 2 + 3j
a_bool = True
a_str = "hello"
a_list = [1, 2]
a_tuple = (1, 2)
a_set = {1, 2}
a_frozenset = frozenset({1, 2})
a_dict = {"x": 1}
a_bytes = b"hi"
a_bytearray = bytearray(b"hi")
a_memoryview = memoryview(b"hi")
a_none = None
a_type = type(42)
a_ellipsis = ...
a_notimpl = NotImplemented

# Collections
a_counter = collections.Counter("abc")
a_ordered = collections.OrderedDict([("a", 1)])
a_default = collections.defaultdict(int)
a_deque = collections.deque([1, 2])
a_chainmap = collections.ChainMap({"a": 1}, {"b": 2})
a_userdict = collections.UserDict()
a_userlist = collections.UserList()
a_userstring = collections.UserString("abc")

# NumPy
a_np_array = np.array([1, 2])
a_np_int = np.int32(7)
a_np_float = np.float64(3.14)
a_np_complex = np.complex128(2 + 3j)
a_np_bool = np.bool_(True)
a_np_str = np.str_("hello")
a_np_obj = np.object_("x")

# Pandas
a_df = pd.DataFrame({"a": [1, 2]})
a_series = pd.Series([1, 2])
a_index = a_df.index
a_multiindex = pd.MultiIndex.from_tuples([("a", 1), ("b", 2)])
a_categorical = pd.Categorical(["a", "b", "a"])
a_timestamp = pd.Timestamp.now()
a_timedelta = pd.Timedelta("1 days")
a_period = pd.Period("2023-01")
a_interval = pd.Interval(1, 5)

# Date & numeric
a_date = datetime.date.today()
a_time = datetime.datetime.now().time()
a_datetime = datetime.datetime.now()
a_timedelta_dt = datetime.timedelta(days=1)
a_decimal = decimal.Decimal("3.14")
a_fraction = fractions.Fraction(2, 3)
a_uuid = uuid.uuid4()
a_range = range(5)
a_slice = slice(1, 3)

# IO & regex
a_file = open("01.txt", "w")
a_stringio = io.StringIO("hi")
a_bytesio = io.BytesIO(b"hi")
a_textio = io.TextIOWrapper(io.BytesIO(b"hi"))
a_pattern = re.compile(r"\d+")
a_match = re.match(r"\d+", "123")

# Pathlib
a_path = pathlib.Path("01.txt")
try:
    a_posix = pathlib.PosixPath("01.txt")
except Exception:
    a_posix = None
try:
    a_winpath = pathlib.WindowsPath("C:\\01.txt")
except Exception:
    a_winpath = None

# Async / coroutine / generator
async def coro(): return 42
with warnings.catch_warnings():
    warnings.simplefilter("ignore", category=RuntimeWarning)
    try:
        a_coro = coro()
    except Exception:
        a_coro = None

async def agen(): yield 42
a_gen = (i for i in range(3))
a_agen = agen()

# Functions & code
def func(): return 1
a_func = func
a_method = str.upper
a_builtin = len
a_namespace = types.SimpleNamespace(x=1)
a_proxy = types.MappingProxyType({"a": 1})
a_code = (lambda x: x).__code__

# Weakref (با کلاس قابل ارجاع)
class Refable: pass
refable_instance = Refable()
a_ref = weakref.ref(refable_instance)
a_proxy_obj = weakref.proxy(refable_instance)

# Array & queue & threading
a_array = array.array("i", [1, 2])
a_queue = queue.Queue()
a_prioqueue = queue.PriorityQueue()
a_lifoqueue = queue.LifoQueue()
a_thread = threading.Thread(target=func)

# Asyncio-safe future/task creation
try:
    loop = asyncio.new_event_loop()
    asyncio.set_event_loop(loop)
    a_future = loop.create_future()
    a_task = loop.create_task(coro())
except Exception:
    a_future = None
    a_task = None

# Class
class MyClass:
    val = 99
    def __init__(self):
        self.x = "hi"
a_obj = MyClass()
